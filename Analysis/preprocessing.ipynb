# %% [markdown]
# First we have to import pandas library using import statement

# %%
import pandas as pd

# %% [markdown]
# - Creating dataset
#
#   - dictionary of items
#   - list of views
#   - importing csv file
#   - importing excel files
#
# - Reading data
# - Selection of data
# - Visualizing the data

# %%
movies = {
  'Title' : ['The Amazing Spider-Man', 'Cars', 'Harry Potter'],
  'Year' : [2014, 2006, 2003],
  'Rating' : [7.0, 6.2, 7.6]
}
pd.DataFrame(movies)
# Out:
#                     Title  Year  Rating
# 0  The Amazing Spider-Man  2014     7.0
# 1                    Cars  2006     6.2
# 2            Harry Potter  2003     7.6

# %%
books = [
  {'Title' : 'Spider-Man','Author' : '', 'Year' : 2016, 'Rating' : 7.5},
  {'Title' : 'Cars','Author' : '', 'Year' : 2009, 'Rating' : 6.8},
  {'Title' : 'Harry Potter','Author' : '', 'Year' : 2005, 'Rating' : 8.1},
  {'Title' : 'The Alchemist','Author' : '', 'Year' : 1988, 'Rating' : 9.2},
  {'Title' : 'The Giirl Next Door','Author' : '', 'Year' : 2002, 'Rating' : 6.7}
]

pd.DataFrame(books)
# Out:
#                  Title Author  Year  Rating
# 0           Spider-Man         2016     7.5
# 1                 Cars         2009     6.8
# 2         Harry Potter         2005     8.1
# 3        The Alchemist         1988     9.2
# 4  The Giirl Next Door         2002     6.7

# %%
import seaborn as sns  #importing seaborn library

# %%
sns.get_dataset_names()  #getting the list of datasets available in seaborn
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')  #loading the titanic dataset

# %%
df #displaying the dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = pd.read_csv('kc_house_data.csv')  #loading the dataset from the csv file

# %%
df  #displaying the dataset
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df .head()  #displaying the first 5 rows of the dataset
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head(69)  #displaying the first 69 rows of the dataset
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000  221900.0         3       1.00         1180
# 1   6414100192  20141209T000000  538000.0         3       2.25         2570
# 2   5631500400  20150225T000000  180000.0         2       1.00          770
# 3   2487200875  20141209T000000  604000.0         4       3.00         1960
# 4   1954400510  20150218T000000  510000.0         3       2.00         1680
# ..         ...              ...       ...       ...        ...          ...
# 64  1189001180  20140603T000000  425000.0         3       2.25         1660
# 65  3253500160  20141120T000000  317625.0         3       2.75         2770
# 66  3394100030  20140909T000000  975000.0         4       2.50         2720
# 67  3717000160  20141009T000000  287000.0         4       2.50         2240
# 68  1274500060  20140825T000000  204000.0         3       1.00         1000
#
# ...

# %%
df.tail()  #displaying the last 5 rows of the dataset
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.tail(40)  #displaying the last 40 rows of the dataset
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21573  8562790760  20140520T000000   785000.0         4       3.50
# 21574  1931300090  20140507T000000   610950.0         3       3.00
# 21575  9578500790  20141111T000000   399950.0         3       2.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21577  3881900317  20150123T000000   579000.0         4       3.25
# 21578   567000385  20140623T000000   362500.0         2       1.50
# 21579  7011201004  20140529T000000   645000.0         3       3.25
# 21580  7853420110  20141003T000000   594866.0         3       3.00
# 21581  7853420110  20150504T000000   625000.0         3       3.00
# 21582  3052700432  20141112T000000   490000.0         3       2.25
# 21583  2025049203  20140610T000000   399950.0         2       1.00
# 21584   952006823  20141202T000000   380000.0         3       2.50
# 21585  3832050760  20140828T000000   270000.0         3       2.50
# ...

# %%
df.info()  #displaying the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()  #displaying the statistical information about the dataset
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe(include = 'object')  #displaying the statistical information about the dataset
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
df.shape  #displaying the shape of the dataset
# Out:
# (21613, 21)

# %%
df.columns  #displaying the columns of the dataset
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.to_list()  #displaying the columns of the dataset in the form of list
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# # **SELECTION OF DATA**
#
# - **_ROW SELECTION_**
#
#   - iloc - index based selection
#   - loc - label baesd selection
#
# - **_COLUMN SELECTION_**
#
#   - Single Column Selection
#
#     - dictionary like selection
#     - object like selection
#
#   - Multiple Column Selection
#     - dictionary like selection

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head() #displaying the first 5 rows of the dataset
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.iloc[1] #displaying the 1st row of the dataset
# Out:
# id                    6414100192
# date             20141209T000000
# price                   538000.0
# bedrooms                       3
# bathrooms                   2.25
# sqft_living                 2570
# sqft_lot                    7242
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  2170
# sqft_basement                400
# yr_built                    1951
# yr_renovated                1991
# zipcode                    98125
# lat                       47.721
# long                    -122.319
# sqft_living15               1690
# sqft_lot15                  7639
# Name: 1, dtype: object

# %%
df.iloc[1:4] #displaying the rows from 1 to 4
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
#
#    sqft_lot15
# 1        7639
# 2        8062
# 3        5000
#
# ...

# %%
df.iloc[[2,3,5,7,9]] #displaying the rows with the given index
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 2  5631500400  20150225T000000   180000.0         2        1.0          770
# 3  2487200875  20141209T000000   604000.0         4        3.0         1960
# 5  7237550310  20140512T000000  1225000.0         4        4.5         5420
# 7  2008000270  20150115T000000   291850.0         3        1.5         1060
# 9  3793500160  20150312T000000   323000.0         3        2.5         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 5    101930     1.0           0     0  ...     11        3890           1530
# 7      9711     1.0           0     0  ...      7        1060              0
# 9      6560     2.0           0     0  ...      7        1890              0
#
# ...

# %%
df.iloc[[2,3,5,7,9], [1,3,5]] #displaying the rows with the given index and columns
# Out:
#               date  bedrooms  sqft_living
# 2  20150225T000000         2          770
# 3  20141209T000000         4         1960
# 5  20140512T000000         4         5420
# 7  20150115T000000         3         1060
# 9  20150312T000000         3         1890

# %%
df = df.set_index('id')

# %%
df.head() #displaying the first 5 rows of the dataset
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[5631500400]
# Out:
# date             20150225T000000
# price                   180000.0
# bedrooms                       2
# bathrooms                    1.0
# sqft_living                  770
# sqft_lot                   10000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          6
# sqft_above                   770
# sqft_basement                  0
# yr_built                    1933
# yr_renovated                   0
# zipcode                    98028
# lat                      47.7379
# long                    -122.233
# sqft_living15               2720
# sqft_lot15                  8062
# Name: 5631500400, dtype: object

# %% [markdown]
# # **COLUMN SELECTION**
#
# - **_Single Column Selection_**
#
#   - dictionary like selection
#   - object like selection
#
# - **_Multiple Column Selection_**
#   - dictionary like selection

# %%
df['price'] #displaying the price column
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.bedrooms #displaying the bedrooms column
# Out:
# id
# 7129300520    3
# 6414100192    3
# 5631500400    2
# 2487200875    4
# 1954400510    3
#              ..
# 263000018     3
# 6600060120    4
# 1523300141    2
# 291310100     3
# 1523300157    2
# Name: bedrooms, Length: 21613, dtype: int64

# %% [markdown]
# # **_Data Cleaning and Manipulation_**
#
# - removing columns
# - renaming columns
# - adding columns
# - changing datatypes of dat
# - handling missing values
# - dropping missing values
# - using apply ( ) method

# %%
df.columns #displaying the columns of the dataset
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols_to_drop = ['sqft_living15', 'sqft_lot15', 'zipcode']
df = df.drop(cols_to_drop, axis = 1) #dropping the columns
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.drop(labels=[7129300520, 6414100192], axis=0, inplace = True) #dropping the rows
df
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...
